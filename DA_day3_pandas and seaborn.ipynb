# %% [markdown]
# PANDAS:
# - USED FOR DATA MANIPULATION(data cleaning,orginizing data)
# - CREATE DATAFRAMES FROM EXCEL,CSV,TXT,DBS
# - DATAFRAME(rows and columns readable by python)
# - DATA CLEANING BY DROPPING OR REPLACING WITH MEAN
# - VISUALIZE THE DATA

# %%
#importing pandas
import pandas as pd

# %%
names=["jwalitha","veena","kusuma","sushmita","teju"]
index=[40,42,42,43,45]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 40    jwalitha
# 42       veena
# 42      kusuma
# 43    sushmita
# 45        teju
# dtype: object

# %% [markdown]
# Importing files
# - for csv and txt:read_csv("file path"
# - for excel:read_excel("file path")

# %%
df=pd.read_csv("/content/grades_withnulls.csv")

# %%
df.head(12)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0

# %%
df.tail()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ")

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dft.tail()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 11   Maya        N   7.7   8.0   7.1     B
# 12  Jolin        K   9.8   9.1   9.9    A+
# 13   Riya        M   8.0   9.1   9.3     A
# 14   Sana        V   9.9   9.3   9.2     A
# 15   Mark        N   7.7   8.0   7.0     B

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")

# %%
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
dfe.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
print(dft.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B>

# %%
print(dfe.describe)
# Out:
# <bound method NDFrame.describe of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
print(df.shape)    #rows and columns
print(df.shape[0])  #rows
print(df.shape[1])   #columns
# Out:
# (17, 7)
# 17
# 7

# %%
print(df.columns)   #headings of colmun names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d8720501884f> in <cell line: 1>()
# ----> 1 print(df.columns)   #headings of colmun names
#
# NameError: name 'df' is not defined

# %%
print(dft.shape)    #rows and columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d61d2f03abcd> in <cell line: 1>()
# ----> 1 print(dft.shape)    #rows and columns
#
# NameError: name 'dft' is not defined

# %%
print(dfe.shape)     #rows and columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0f8db4503032> in <cell line: 1>()
# ----> 1 print(dfe.shape)     #rows and columns
#
# NameError: name 'dfe' is not defined

# %% [markdown]
# accesing data
# loc - accepts columns names and index,
# iloc - accepts only index

# %%
print(dft[2:5])   #to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5,"Names"])    #rows of specified columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9023842667c5> in <cell line: 1>()
# ----> 1 print(dft.loc[2:5,"Names"])    #rows of specified columns
#
# NameError: name 'dft' is not defined

# %%
print(dft.iloc[2:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c588c55f8f43> in <cell line: 1>()
# ----> 1 print(dft.iloc[2:5])
#
# NameError: name 'dft' is not defined

# %%
print(dft.iloc[2:5, :3])   #iloc[row range,column range]=>index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-63c069564549> in <cell line: 1>()
# ----> 1 print(dft.iloc[2:5, :3])   #iloc[row range,column range]=>index
#
# NameError: name 'dft' is not defined

# %%
import seaborn as sns
import numpy as np

# %%
dfe['Index']=range(1,769)
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive      5

# %%
df.head(756)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# datasets-
# tips
# dowjenos
# fmri
# dots
# healthexp
# to dataset use:
# load_load_dataset("dataset_name")

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
do=sns.load_dataset("dowjones")
do.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
f=sns.load_dataset("fmri")
f.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
d=sns.load_dataset("dots")
d.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.replot(data=tips,x="total_bill",y="tip",hue="smoker",style="time")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-55e7454edb5a> in <cell line: 1>()
# ----> 1 sns.replot(data=tips,x="total_bill",y="tip",hue="smoker",style="time")
#
# AttributeError: module 'seaborn' has no attribute 'replot'

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
print(type(dowjones))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
sns.catplot(data=tips,x="total_bill",y='day')

# %%
sns.catplot(data=tips,y="total_bill",x='time',kind="violin",hue="smoker")

# %% [markdown]
# linear fit:
# - implot is function
# -

# %%
sns.lmplot(x="size",y="tip",data=tips);
