# %% [markdown]
# LIBRARIES
# - beautiful soup
# - requests
# - selenium
# - pandas
# - webdriver
# - webdriver_manager
# - to install any library:
# !pip install library,!pip install --upgrade library # to upgrade to recent version
# - importing subpackage:from parent import child
#
#
# BEAUTIFULSOUP
# - used to scrape data from static website
# - package bs4:subpackage beautifulsoup
# FUNCTION         PURPOSE       ATTRIBUTES
# - beautifulsoup()

# %% [markdown]
# WEB SCRAPPING
# 1.extracting html code of any website

# %%
#import libraries
from bs4 import BeautifulSoup    #beautifulsoup is subpackage of bs4
import requests

# %%
url="https://drive.google.com/drive/u/0/home"
page=requests.get(url)
#accesing the html code
s=BeautifulSoup(page.text,"html")
print(s)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ACCESING THE TABLE FROM WEBPAGE
